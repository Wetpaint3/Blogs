# %% [markdown]
# ## Monte Carlo Simulations in Python

# %%
import random

def rollDice():
    roll = random.randint(1,100)
    return roll

# %%
rollDice()
# Out:
# 60

# %%
x = 0
while x < 100:
    result = rollDice()
    print(result)
    x+=1
# Out:
# 14
# 69
# 91
# 68
# 83
# 61
# 59
# 18
# 83
# 3
# 39
# 86
# 76
# 70
# 28
# 13
# 33
# 87
# 58
# 77
# 31
# 7
# 16
# 35
# 95
# 6
# 8
# 20
# 42
# 87
# 81
# 25
# 61
# 83
# 90
# 92
# 57
# 93
# 20
# 23
# 34
# 50
# 17
# 4
# 31
# 3
# 82
# 39
# 33
# 21
# 93
# 91
# 54
# 22
# 44
# 88
# 38
# 94
# 65
# 54
# 92
# 3
# 49
# 12
# 17
# 34
# 44
# 61
# 30
# 20
# 63
# 90
# 42
# 77
# 78
# 12
# 64
# 35
# 90
# 7
# 9
# 27
# 79
# 42
# 80
# 66
# 63
# 26
# 95
# 35
# 73
# 98
# 1
# 88
# 91
# 56
# 68
# 41
# 67
# 54

# %%
import random


# let us go ahead and change this to return a simple win/loss
def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        print(roll,'roll was 100, you lose. What are the odds?! Play again!')
        return False
    elif roll <= 50:
        print(roll,'roll was 1-50, you lose.')
        return False
    elif 100 > roll >= 50:
        print(roll,'roll was 51-99, you win! *pretty lights flash* (play more!)')
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    currentWager = 0

    while currentWager < wager_count:
        if rollDice():
            value += wager
        else:
            value -= wager

        currentWager += 1
        print('Funds:'), value



simple_bettor(10000,100,100)
# Out:
# 44 roll was 1-50, you lose.
# Funds:
# 50 roll was 1-50, you lose.
# Funds:
# 72 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 25 roll was 1-50, you lose.
# Funds:
# 21 roll was 1-50, you lose.
# Funds:
# 54 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 89 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 78 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 97 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 82 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 79 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 59 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 28 roll was 1-50, you lose.
# Funds:
# 70 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 32 roll was 1-50, you lose.
# Funds:
# 60 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 44 roll was 1-50, you lose.
# Funds:
# 74 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 44 roll was 1-50, you lose.
# Funds:
# 67 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 54 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 100 roll was 100, you lose. What are the odds?! Play again!
# Funds:
# 97 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 90 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 40 roll was 1-50, you lose.
# Funds:
# 13 roll was 1-50, you lose.
# Funds:
# 54 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 20 roll was 1-50, you lose.
# Funds:
# 62 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 35 roll was 1-50, you lose.
# Funds:
# 98 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 47 roll was 1-50, you lose.
# Funds:
# 43 roll was 1-50, you lose.
# Funds:
# 19 roll was 1-50, you lose.
# Funds:
# 62 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 19 roll was 1-50, you lose.
# Funds:
# 65 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 47 roll was 1-50, you lose.
# Funds:
# 28 roll was 1-50, you lose.
# Funds:
# 65 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 15 roll was 1-50, you lose.
# Funds:
# 13 roll was 1-50, you lose.
# Funds:
# 90 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 31 roll was 1-50, you lose.
# Funds:
# 70 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 31 roll was 1-50, you lose.
# Funds:
# 74 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 39 roll was 1-50, you lose.
# Funds:
# 45 roll was 1-50, you lose.
# Funds:
# 47 roll was 1-50, you lose.
# Funds:
# 55 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 76 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 51 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 31 roll was 1-50, you lose.
# Funds:
# 40 roll was 1-50, you lose.
# Funds:
# 54 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 90 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 83 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 13 roll was 1-50, you lose.
# Funds:
# 85 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 60 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 66 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 97 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 62 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 7 roll was 1-50, you lose.
# Funds:
# 61 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 13 roll was 1-50, you lose.
# Funds:
# 86 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 56 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 5 roll was 1-50, you lose.
# Funds:
# 31 roll was 1-50, you lose.
# Funds:
# 52 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 99 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 14 roll was 1-50, you lose.
# Funds:
# 26 roll was 1-50, you lose.
# Funds:
# 14 roll was 1-50, you lose.
# Funds:
# 22 roll was 1-50, you lose.
# Funds:
# 99 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 48 roll was 1-50, you lose.
# Funds:
# 46 roll was 1-50, you lose.
# Funds:
# 19 roll was 1-50, you lose.
# Funds:
# 90 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 50 roll was 1-50, you lose.
# Funds:
# 83 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 67 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 96 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 84 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 37 roll was 1-50, you lose.
# Funds:
# 23 roll was 1-50, you lose.
# Funds:
# 95 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 81 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 63 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 80 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 65 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 34 roll was 1-50, you lose.
# Funds:
# 40 roll was 1-50, you lose.
# Funds:
# 94 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:
# 33 roll was 1-50, you lose.
# Funds:
# 15 roll was 1-50, you lose.
# Funds:
# 53 roll was 51-99, you win! *pretty lights flash* (play more!)
# Funds:

# %%
import random


# let us go ahead and change this to return a simple win/loss
def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        #print roll,'roll was 100, you lose. What are the odds?! Play again!'
        return False
    elif roll <= 50:
        #print roll,'roll was 1-50, you lose.'
        return False
    elif 100 > roll >= 50:
        #print roll,'roll was 51-99, you win! *pretty lights flash* (play more!)'
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    currentWager = 0

    while currentWager < wager_count:
        if rollDice():
            value += wager
        else:
            value -= wager

        currentWager += 1

    # changed to reduce spam
    if value < 0:
        value = 'Broke!'
    print('Funds:', value)

# lots of wagers now....
x = 0

while x < 100:
    simple_bettor(10000,100,50)
    x += 1
# Out:
# Funds: 9800
# Funds: 10200
# Funds: 9800
# Funds: 8600
# Funds: 9000
# Funds: 10400
# Funds: 9600
# Funds: 10200
# Funds: 10600
# Funds: 9800
# Funds: 10000
# Funds: 11600
# Funds: 11200
# Funds: 9400
# Funds: 10200
# Funds: 10400
# Funds: 10800
# Funds: 10000
# Funds: 10200
# Funds: 9800
# Funds: 10800
# Funds: 9000
# Funds: 10600
# Funds: 9400
# Funds: 10000
# Funds: 8800
# Funds: 10200
# Funds: 10400
# Funds: 9000
# Funds: 9200
# Funds: 10400
# Funds: 10800
# Funds: 10000
# Funds: 9200
# Funds: 10800
# Funds: 10200
# Funds: 10600
# Funds: 10600
# Funds: 10400
# Funds: 9800
# Funds: 10000
# Funds: 9600
# Funds: 10000
# Funds: 10000
# Funds: 9400
# Funds: 8800
# Funds: 9000
# Funds: 11200
# Funds: 9400
# Funds: 9000
# Funds: 8800
# Funds: 10000
# Funds: 9000
# Funds: 9600
# Funds: 9600
# Funds: 9600
# Funds: 8800
# Funds: 8600
# Funds: 10400
# Funds: 10000
# Funds: 10600
# Funds: 10000
# Funds: 9200
# Funds: 10800
# Funds: 10400
# Funds: 9600
# Funds: 10800
# Funds: 9000
# Funds: 10200
# Funds: 9800
# Funds: 11000
# Funds: 9400
# Funds: 11600
# Funds: 9600
# Funds: 9600
# Funds: 8800
# Funds: 9600
# Funds: 9000
# Funds: 10600
# Funds: 10200
# Funds: 9000
# Funds: 10200
# Funds: 9800
# Funds: 10400
# Funds: 10200
# Funds: 10000
# Funds: 10000
# Funds: 9400
# Funds: 11600
# Funds: 10800
# Funds: 10000
# Funds: 10200
# Funds: 10200
# Funds: 10000
# Funds: 10200
# Funds: 10200
# Funds: 9400
# Funds: 9400
# Funds: 9400
# Funds: 8400

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(10000,100,100)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('Thousand_trails')
plt.show()

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(10000,100,100000)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('100K_trails')
plt.show()

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(10000,100,1000000)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('Mln_trails')
plt.show()

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(1000,100,100000)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('Mln_trails')
plt.show()

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(1000,10,100000)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('Mln_trails')
plt.show()

# %%
import random
import matplotlib
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(1,100)

    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll >= 50:
        return True


'''
Simple bettor, betting the same amount each time.
'''
def simple_bettor(funds,initial_wager,wager_count):
    value = funds
    wager = initial_wager

    # wager X
    wX = []

    #value Y
    vY = []

    # change to 1, to avoid confusion so we start @ wager 1
    # instead of wager 0 and end at 100. 
    currentWager = 1

    #           change this to, less or equal.
    while currentWager <= wager_count:
        if rollDice():
            value += wager
            # append #
            wX.append(currentWager)
            vY.append(value)
            
        else:
            value -= wager
            # append #
            wX.append(currentWager)
            vY.append(value)

        currentWager += 1
        
    #print 'Funds:', value

    plt.plot(wX,vY)
    


x = 0

# start this off @ 1, then add, and increase 50 to 500, then 1000
while x < 100:
    simple_bettor(100,100,100)
    x += 1


plt.ylabel('Account Value')
plt.xlabel('Wager Count')
plt.savefig('Mln_trails')
plt.show()
